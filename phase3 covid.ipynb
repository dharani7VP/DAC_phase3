# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
covid=pd.read_csv("Covid_19_cases4.csv")
covid
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories
# 0     31-05-2021   31      5  2021    366       5                 Austria
# 1     30-05-2021   30      5  2021    570       6                 Austria
# 2     29-05-2021   29      5  2021    538      11                 Austria
# 3     28-05-2021   28      5  2021    639       4                 Austria
# 4     27-05-2021   27      5  2021    405      19                 Austria
# ...          ...  ...    ...   ...    ...     ...                     ...
# 2725  06-03-2021    6      3  2021   3455      17                  Sweden
# 2726  05-03-2021    5      3  2021   4069      12                  Sweden
# 2727  04-03-2021    4      3  2021   4884      14                  Sweden
# 2728  03-03-2021    3      3  2021   4876      19                  Sweden
# 2729  02-03-2021    2      3  2021   6191      19                  Sweden
#
# [2730 rows x 7 columns]

# %%
covid.describe()
# Out:
#                day        month    year         cases       deaths
# count  2730.000000  2730.000000  2730.0   2730.000000  2730.000000
# mean     16.000000     4.010989  2021.0   3661.010989    65.291941
# std       8.765919     0.818813     0.0   6490.510073   113.956634
# min       1.000000     3.000000  2021.0  -2001.000000    -3.000000
# 25%       8.000000     3.000000  2021.0    361.250000     2.000000
# 50%      16.000000     4.000000  2021.0    926.500000    14.500000
# 75%      24.000000     5.000000  2021.0   3916.250000    72.000000
# max      31.000000     5.000000  2021.0  53843.000000   956.000000

# %%
covid.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2730 entries, 0 to 2729
# Data columns (total 7 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   dateRep                  2730 non-null   object
#  1   day                      2730 non-null   int64
#  2   month                    2730 non-null   int64
#  3   year                     2730 non-null   int64
#  4   cases                    2730 non-null   int64
#  5   deaths                   2730 non-null   int64
#  6   countriesAndTerritories  2730 non-null   object
# dtypes: int64(5), object(2)
# memory usage: 149.4+ KB

# %%
x=covid.drop("deaths",axis=1)
y=covid['deaths']
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.5,random_state=0)
x_train
# Out:
#          dateRep  day  month  year  cases countriesAndTerritories
# 965   06-04-2021    6      4  2021   6885                 Germany
# 1935  07-05-2021    7      5  2021   6781             Netherlands
# 1080  13-03-2021   13      3  2021   2357                  Greece
# 632   06-03-2021    6      3  2021    614                 Denmark
# 1864  17-04-2021   17      4  2021     27                   Malta
# ...          ...  ...    ...   ...    ...                     ...
# 1731  29-05-2021   29      5  2021     81              Luxembourg
# 763   26-04-2021   26      4  2021    460                 Finland
# 835   15-05-2021   15      5  2021  17415                  France
# 1653  16-05-2021   16      5  2021   1249               Lithuania
# 2607  02-04-2021    2      4  2021      0                   Spain
#
# [1365 rows x 6 columns]

# %%
x_train.shape
# Out:
# (1365, 6)

# %%
x_test.shape
# Out:
# (1365, 6)

# %%
y_train.shape
# Out:
# (1365,)

# %%
y_test.shape
# Out:
# (1365,)

# %%
y_test
# Out:
# 578      2
# 2242     9
# 2690    16
# 70      19
# 758      0
#         ..
# 1549     0
# 308     39
# 1001    30
# 1651     9
# 143     44
# Name: deaths, Length: 1365, dtype: int64

# %%
x_test
# Out:
#          dateRep  day  month  year  cases countriesAndTerritories
# 578   29-04-2021   29      4  2021    835                 Denmark
# 2242  03-04-2021    3      4  2021    548                Portugal
# 2690  10-04-2021   10      4  2021   5628                  Sweden
# 70    22-03-2021   22      3  2021   2918                 Austria
# 758   01-05-2021    1      5  2021    195                 Finland
# ...          ...  ...    ...   ...    ...                     ...
# 1549  29-05-2021   29      5  2021      2           Liechtenstein
# 308   26-04-2021   26      4  2021   1254                 Croatia
# 1001  31-05-2021   31      5  2021    906                  Greece
# 1651  18-05-2021   18      5  2021    527               Lithuania
# 143   09-04-2021    9      4  2021   4480                 Belgium
#
# [1365 rows x 6 columns]

# %%
x
# Out:
#          dateRep  day  month  year  cases countriesAndTerritories
# 0     31-05-2021   31      5  2021    366                 Austria
# 1     30-05-2021   30      5  2021    570                 Austria
# 2     29-05-2021   29      5  2021    538                 Austria
# 3     28-05-2021   28      5  2021    639                 Austria
# 4     27-05-2021   27      5  2021    405                 Austria
# ...          ...  ...    ...   ...    ...                     ...
# 2725  06-03-2021    6      3  2021   3455                  Sweden
# 2726  05-03-2021    5      3  2021   4069                  Sweden
# 2727  04-03-2021    4      3  2021   4884                  Sweden
# 2728  03-03-2021    3      3  2021   4876                  Sweden
# 2729  02-03-2021    2      3  2021   6191                  Sweden
#
# [2730 rows x 6 columns]

# %%
display(covid.drop_duplicates())
# Out:
#          dateRep  day  month  year  cases  deaths countriesAndTerritories
# 0     31-05-2021   31      5  2021    366       5                 Austria
# 1     30-05-2021   30      5  2021    570       6                 Austria
# 2     29-05-2021   29      5  2021    538      11                 Austria
# 3     28-05-2021   28      5  2021    639       4                 Austria
# 4     27-05-2021   27      5  2021    405      19                 Austria
# ...          ...  ...    ...   ...    ...     ...                     ...
# 2725  06-03-2021    6      3  2021   3455      17                  Sweden
# 2726  05-03-2021    5      3  2021   4069      12                  Sweden
# 2727  04-03-2021    4      3  2021   4884      14                  Sweden
# 2728  03-03-2021    3      3  2021   4876      19                  Sweden
# 2729  02-03-2021    2      3  2021   6191      19                  Sweden
#
# [2730 rows x 7 columns]

# %%
plt.plot(covid.cases,covid.deaths)
plt.xlabel('covid.cases')
plt.ylabel('covid.deaths')
plt.title('covid graph')
plt.show()
